# %%
import pandas as pd
from operator import itemgetter
import ast

df = pd.read_csv('../data/1_predicted_category_documents.csv')

# %%
df[df['content'].str.lower().str.contains("sea of okhotsk")]
# Out:
#        Unnamed: 0       id                                            content  \
# 527           527   324139  A comparative analysis was conducted on climat...
# 1883         1883  1397385  Changes in composition of planktonic foraminif...
# 3875         3875  2311496  Long chain diols have been detected in a wide ...
# 9159         9159  1452749  The genetic variability distribution of two mt...
# 10075       10075   735147  Hokkaido is classified into five regions based...
# 13339       13339     4717  We have reviewed the effects of long-term clim...
# 14577       14577   673865  The Bering Sea gateway between the Pacific and...
# 17962       17962   318269  The Arctic sea ice retreat has accelerated ove...
# 24228       24228  1523239  During the period 1954-2014, concentrations of...
# 31092       31092  1554478  Consecutive extreme rainfall (CER) events can ...
# 32658       32658  1391611  The relationship between extreme anomalies of ...
# 33518       33518  1470864  This study examined the quiescence of Asian du...
# 40739       40739   700902  Recent studies have revealed the impact of the...
# 41664       41664   555438  This study aims to investigate the recent drou...
# 43797       43797  1536801  The Pacific Japan (PJ) teleconnection pattern ...
# 44362       44362  2306490  This study investigates how Eurasian snow cove...
# 45802       45802  2325309  Changing climate patterns strongly influence m...
# 49469       49469  1884338  The article presents the results of studying t...
# 50817       50817   125246  The winters of 1999-2002 for the North Pacific...
# 54163       54163  1501620  This study examines pre-industrial control sim...
# 55255       55255  3826759  Knowledge of past variations in sea-ice extent...
# 55748       55748  1416553  Northern Hemisphere sea ice concentration, 500...
# 56546       56546  1387987  BACKGROUND: The relationship between cold resi...
# 58471       58471  3300112  [1] Ice draft, ice velocity, ice concentration...
# 58826       58826   493919  Lithological, geochemical, and micropaleontolo...
# 60104       60104  1532255  The seasonal change in the development of Aleu...
# 64820       64820  1481496  Using path analyses, we investigated relations...
# 73927       73927   257353  We re-examined sixteen pollen records from non...
# 76430       76430  1376417  [ 1] The 18.6-year lunar nodal cycle (LNC) is ...
# 77025       77025  1320100  A reconstruction of theclimate and hydrology o...
# 77369       77369  1315381  The slowly evolving annual cycle (signified as...
# 77478       77478  1806323  Significant abundance changes of seven radiola...
# 83605       83605    95092  The possibility of an asymmetric response of s...
# 85750       85750  1372413  The species and quantitative composition of be...
# 86241       86241   145825  The relationship between the Arctic and subarc...
# 87801       87801   416478  The distribution, diversity and structure of b...
# 89690       89690  1353238  Changes in snowline elevation and dust flux cl...
# 91270       91270  3315610  We performed a comprehensive analysis of satel...
# 92085       92085  1492525  By using NCEP/NCAR reanalysis datasets, the le...
# 93573       93573  1531076  This article provides a brief review of climat...
# 93578       93578  3314627  Explosive cyclones formed in the northwest Pac...
# 95489       95489   777861  Sclerochronological and shell stable oxygen is...
#
#                                                    title  \
# 527    Comparison of atmospheric forcing in four sub-...
# 1883   The history of circulation in the Sea of Okhot...
# 3875   A multiproxy study of past environmental chang...
# 9159   Genetic variability in anadromous fishes, chum...
# 10075  Holocene vegetation and climate on Hokkaido Is...
# 13339  Effect of global warming on the life history a...
# 14577  Last Glacial Maximum to Holocene sea surface c...
# 17962  Observed anomalous atmospheric patterns in sum...
# 24228  Decline and Bidecadal Oscillations of Dissolve...
# 85750                                                NaN
# 86241                                                NaN
# 87801  boreal forests; forest vegetation pattern; Mon...
# 89690                                                NaN
# 91270                                                NaN
# 92085  Yangtze-Huaihe river valley; season division; ...
# 93573  climate; currents; demersal fish; herring; reg...
# 93578  Storm surge; explosive cyclogenesis; winter st...
# 95489  Mercenaries stimpsoni; Sea of Okhotsk; Scleroc...
#
#                                           wosarticle__wc  ar5  seen  relevant  \
# 527                                     ['Oceanography']  NaN   0.0       0.0
# 1883                           ['Geology; Paleontology']  NaN   0.0       0.0
# 3875                       ['Geochemistry & Geophysics']  NaN   0.0       0.0
# 9159                     ['Marine & Freshwater Biology']  NaN   0.0       0.0
# 10075  ['Geography, Physical; Geosciences, Multidisci...  NaN   0.0       0.0
# 13339                                      ['Fisheries']  NaN   0.0       0.0
# 14577  ['Geosciences, Multidisciplinary; Oceanography...  NaN   0.0       0.0
# 17962             ['Meteorology & Atmospheric Sciences']  NaN   0.0       0.0
# 24228  ['Environmental Sciences; Geosciences, Multidi...  0.0   1.0       0.0
# 31092             ['Meteorology & Atmospheric Sciences']  NaN   0.0       0.0
# 32658             ['Meteorology & Atmospheric Sciences']  NaN   0.0       0.0
# 33518  ['Environmental Sciences; Meteorology & Atmosp...  NaN   0.0       0.0
# 40739                                        ['Zoology']  NaN   0.0       0.0
# 41664                     ['Physics, Multidisciplinary']  NaN   0.0       0.0
# 43797             ['Meteorology & Atmospheric Sciences']  NaN   0.0       0.0
# 44362             ['Meteorology & Atmospheric Sciences']  NaN   0.0       0.0
# 45802  ['Environmental Sciences; Marine & Freshwater ...  NaN   0.0       0.0
# 49469  ['Green & Sustainable Science & Technology; En...  NaN   0.0       0.0
# 50817                 ['Geosciences, Multidisciplinary']  NaN   0.0       0.0
# 54163             ['Meteorology & Atmospheric Sciences']  NaN   0.0       0.0
# 55255                                   ['Paleontology']  NaN   0.0       0.0
# 55748             ['Meteorology & Atmospheric Sciences']  NaN   0.0       0.0
# 56546                            ['Biology; Physiology']  NaN   0.0       0.0
# 58471                                   ['Oceanography']  NaN   0.0       0.0
# 58826                                   ['Oceanography']  NaN   0.0       0.0
# 60104                                   ['Oceanography']  NaN   0.0       0.0
# 64820                        ['Fisheries; Oceanography']  NaN   0.0       0.0
# 73927                   ['Plant Sciences; Paleontology']  NaN   0.0       0.0
# 76430                                   ['Oceanography']  NaN   0.0       0.0
# 77025                                   ['Oceanography']  NaN   0.0       0.0
# 77369             ['Meteorology & Atmospheric Sciences']  NaN   0.0       0.0
# 77478  ['Geography, Physical; Geosciences, Multidisci...  NaN   0.0       0.0
# 83605             ['Meteorology & Atmospheric Sciences']  NaN   0.0       0.0
# 85750                                   ['Oceanography']  NaN   0.0       0.0
# 86241  ['Meteorology & Atmospheric Sciences; Oceanogr...  NaN   0.0       0.0
# 87801              ['Plant Sciences; Ecology; Forestry']  NaN   0.0       0.0
# 89690  ['Geography, Physical; Geosciences, Multidisci...  NaN   0.0       0.0
# 91270  ['Remote Sensing; Imaging Science & Photograph...  NaN   0.0       0.0
# 92085                     ['Physics, Multidisciplinary']  NaN   0.0       0.0
# 93573  ['Fisheries; Marine & Freshwater Biology; Ocea...  NaN   0.0       0.0
# 93578         ['Engineering, Civil; Engineering, Ocean']  NaN   0.0       0.0
# 95489  ['Geography, Physical; Geosciences, Multidisci...  NaN   0.0       0.0
#
#        random_sample  ...  \
# 527                0  ...
# 1883               0  ...
# 3875               0  ...
# 9159               0  ...
# 10075              0  ...
# 13339              0  ...
# 14577              0  ...
# 17962              0  ...
# 24228              1  ...
# 31092              0  ...
# 32658              0  ...
# 33518              0  ...
# 40739              0  ...
# 41664              0  ...
# 43797              0  ...
# 44362              0  ...
# 45802              0  ...
# 49469              0  ...
# 50817              0  ...
# 54163              0  ...
# 55255              0  ...
# 55748              0  ...
# 56546              0  ...
# 58471              0  ...
# 58826              0  ...
# 60104              0  ...
# 64820              0  ...
# 73927              0  ...
# 76430              0  ...
# 77025              0  ...
# 77369              0  ...
# 77478              0  ...
# 83605              0  ...
# 85750              0  ...
# 86241              0  ...
# 87801              0  ...
# 89690              0  ...
# 91270              0  ...
# 92085              0  ...
# 93573              0  ...
# 93578              0  ...
# 95489              0  ...
#
#        2 - Trend or climate change attribution - upper_pred  \
# 527                                             0.758258
# 1883                                            0.600000
# 3875                                            1.000000
# 9159                                            0.600000
# 10075                                           0.000000
# 13339                                           0.400000
# 14577                                           1.000000
# 17962                                           1.000000
# 24228                                                NaN
# 31092                                           1.000000
# 32658                                           0.000000
# 33518                                           1.000000
# 40739                                           0.000000
# 41664                                           0.000000
# 43797                                           1.000000
# 44362                                           0.400000
# 45802                                           1.000000
# 49469                                           1.000000
# 50817                                           0.400000
# 54163                                           0.000000
# 55255                                           0.000000
# 55748                                           1.000000
# 56546                                           0.000000
# 58471                                           0.000000
# 58826                                           1.000000
# 60104                                           1.000000
# 64820                                           0.000000
# 73927                                           1.000000
# 76430                                           0.889898
# 77025                                           0.889898
# 77369                                           0.400000
# 77478                                           0.000000
# 83605                                           1.000000
# 85750                                           0.889898
# 86241                                           1.000000
# 87801                                           1.000000
# 89690                                           0.000000
# 91270                                           1.000000
# 92085                                           0.600000
# 93573                                           1.000000
# 93578                                           0.400000
# 95489                                           1.000000
#
#        2 - 2.4. Sensitivity - mean_prediction  \
# 527                                       0.0
# 1883                                      0.0
# 3875                                      0.0
# 9159                                      0.4
# 10075                                     0.0
# 13339                                     0.0
# 14577                                     0.0
# 17962                                     0.0
# 24228                                     NaN
# 31092                                     0.0
# 32658                                     0.8
# 33518                                     0.0
# 40739                                     0.9
# 41664                                     0.0
# 43797                                     0.8
# 44362                                     1.0
# 45802                                     0.1
# 49469                                     0.0
# 50817                                     0.0
# 54163                                     0.1
# 55255                                     0.0
# 55748                                     0.0
# 56546                                     1.0
# 58471                                     0.0
# 58826                                     0.0
# 60104                                     0.0
# 64820                                     0.2
# 73927                                     0.0
# 76430                                     0.1
# 77025                                     0.0
# 77369                                     0.9
# 77478                                     0.0
# 83605                                     0.0
# 85750                                     0.0
# 86241                                     0.0
# 87801                                     0.0
# 89690                                     1.0
# 91270                                     0.0
# 92085                                     0.6
# 93573                                     0.0
# 93578                                     0.4
# 95489                                     0.0
#
#        2 - 2.4. Sensitivity - std_prediction  \
# 527                                 0.000000
# 1883                                0.000000
# 3875                                0.000000
# 9159                                0.489898
# 10075                               0.000000
# 13339                               0.000000
# 14577                               0.000000
# 17962                               0.000000
# 24228                                    NaN
# 31092                               0.000000
# 32658                               0.400000
# 33518                               0.000000
# 40739                               0.300000
# 41664                               0.000000
# 43797                               0.400000
# 44362                               0.000000
# 45802                               0.300000
# 49469                               0.000000
# 50817                               0.000000
# 54163                               0.300000
# 527    2007.0
# 1883   2015.0
# 3875   2018.0
# 9159   2016.0
# 10075  2013.0
# 13339  1991.0
# 14577  2012.0
# 17962  2006.0
# 24228  2017.0
# 31092  2017.0
# 32658  2015.0
# 33518  2016.0
# 40739  2012.0
# 41664  2010.0
# 43797  2017.0
# 44362  2018.0
# 45802  2018.0
# 49469  2017.0
# 50817  2001.0
# 54163  2017.0
# 55255     NaN
# 55748  2016.0
# 56546  2015.0
# 58471  2019.0
# 58826  2009.0
# 60104  2017.0
# 64820  2016.0
# 73927  2005.0
# 76430  2015.0
# 77025  2015.0
# 77369  2015.0
# 77478  2017.0
# 83605  1999.0
# 85750  2015.0
# 86241  2002.0
# 87801  2008.0
# 89690  2015.0
# 91270  2019.0
# 92085  2016.0
# 93573  2017.0
# 93578  2019.0
# 95489  2013.0
#
# [42 rows x 296 columns]

# %%
places = pd.read_csv('../data/places.csv')
places = places[places['country_conf']>0.4]
places = places[pd.notnull(places["place_name"])]

gm_docs = df.loc[
    (df['title'].str.lower().str.contains("gulf of mexico")) |
    (df['content'].str.lower().str.contains("gulf of mexico")),
    "id"
]
geocolumns = ["word", "country_conf", "feature_code","lat","lon","place_name","feature_class","geonameid"]
gm = pd.DataFrame({"doc_id": gm_docs})
gm[geocolumns] = ["Gulf of Mexico",0.8,"GULF", 25, -90, "Gulf of Mexico", "H", 3523271]


lab_docs = df.loc[
    (df['title'].str.lower().str.contains("labrador sea")) |
    (df['content'].str.lower().str.contains("labrador sea")),
    "id"
]
geocolumns = ["word", "country_conf", "feature_code","lat","lon","place_name","feature_class","geonameid"]
lab = pd.DataFrame({"doc_id": lab_docs})
lab[geocolumns] = ["Labrador Sea",0.8,"SEA", 57, -55, "Labrador Sea", "H", 3424929]

baf_docs = df.loc[
    (df['title'].str.lower().str.contains("baffin bay")) |
    (df['content'].str.lower().str.contains("baffin bay")),
    "id"
]
geocolumns = ["word", "country_conf", "feature_code","lat","lon","place_name","feature_class","geonameid"]
baf = pd.DataFrame({"doc_id": baf_docs})
baf[geocolumns] = ["Baffin Bay",0.8,"BAY", 74, -68, "Baffin Bay", "H", 3831554]

ok_docs = df.loc[
    (df['title'].str.lower().str.contains("sea of okhotsk")) |
    (df['content'].str.lower().str.contains("sea of okhotsk")),
    "id"
]
geocolumns = ["word", "country_conf", "feature_code","lat","lon","place_name","feature_class","geonameid"]
ok = pd.DataFrame({"doc_id": baf_docs})
ok[geocolumns] = ["Sea of Okhotsk",0.8, "SEA", 55, 150, "Sea of Okhotsk", "H", 2127380]

places = pd.concat([places, gm, lab, baf, ok])

places.tail()
# Out:
#                  word spans country_predicted  country_conf   doc_id admin1  \
# 91550  Sea of Okhotsk   NaN               NaN           0.8  2354419    NaN
# 92351  Sea of Okhotsk   NaN               NaN           0.8   169562    NaN
# 93969  Sea of Okhotsk   NaN               NaN           0.8   572968    NaN
# 93997  Sea of Okhotsk   NaN               NaN           0.8  1898289    NaN
# 95679  Sea of Okhotsk   NaN               NaN           0.8  1280991    NaN
#
#         lat    lon country_code3  geonameid      place_name feature_class  \
# 91550  55.0  150.0           NaN  2127380.0  Sea of Okhotsk             H
# 92351  55.0  150.0           NaN  2127380.0  Sea of Okhotsk             H
# 93969  55.0  150.0           NaN  2127380.0  Sea of Okhotsk             H
# 93997  55.0  150.0           NaN  2127380.0  Sea of Okhotsk             H
# 95679  55.0  150.0           NaN  2127380.0  Sea of Okhotsk             H
#
#       feature_code
# 91550          SEA
# 92351          SEA
# 93969          SEA
# 93997          SEA
# 95679          SEA

# %%
geocolumns = ["feature_code","lat","lon","place_name","feature_class","geonameid"]
places.loc[places["word"]=="Pakistan", geocolumns]=["PCLI",30,70,"Islamic Republic of Pakistan","A",1168579]
places.loc[places["word"]=="Colombia", geocolumns]=["PCLI",4,-73.25,"Colombia","A",3686110]
places.loc[places["word"]=="Argentina", geocolumns]=["PCLI",-34,-64,"Argentine Republic","A",3865483]
places.loc[places["word"]=="Sahara", geocolumns] = ["DSRT", 26, 13, "Sahara", "T", 2212709]
places.loc[places["word"]=="Alps",geocolumns] = ["MTS", 46.41667, 10, "Alps", "T", 2661786]
places.loc[places["word"]=="Mediterranean Sea",geocolumns] = ["SEA", 35, 20, "Mediterranean Sea", "T", 2661786]
places.loc[places["word"]=="MEDITERRANEAN",geocolumns] = ["SEA", 35, 20, "Mediterranean Sea", "T", 2661786]
places.loc[places["word"]=="East China",geocolumns] = ["PCLI", 35, 105, "China", "A", 1814991]
places.loc[places["word"]=="South China",geocolumns] = ["PCLI", 35, 105, "China", "A", 1814991]
places.loc[places["word"]=="Great Lakes",geocolumns] = ["LK", 45.68751, -84.43753, "Great Lakes", "H", 4994594]
places.loc[places["word"]=="Catalonia",geocolumns] = ["ADM1", 41.82046, 1.86768, "Catalunya", "A", 3336901]
places.loc[places["word"]=="South Pacific",geocolumns] = ["OCN", -45, -130, "South Pacific Ocean", "H", 4030483]
places.loc[places["word"]=="Gulf Coast",geocolumns] = ["AREA", 29.36901, -95.00565, "Gulf Coast", "L", 7287689]
places.loc[places["word"]=="Gulf coast",geocolumns] = ["AREA", 29.36901, -95.00565, "Gulf Coast", "L", 7287689]
places.loc[places["word"]=="Hainan Island",geocolumns] = ["ISL", 19.2, 109.7, "Hainan Dao", "T", 1809055]
places.loc[places["word"]=="Red Sea",geocolumns] = ["SEA", 20.26735, 38.53455, "Red Sea", "H", 350155]
places.loc[places["word"]=="Himalayan",geocolumns] = ["MTS", 28,84, "Himalayas", "T", 1252558]
places.loc[places["word"]=="Himalayas",geocolumns] = ["MTS", 28,84, "Himalayas", "T", 1252558]
places.loc[places["word"]=="North America's",geocolumns] = ["CONT", 46.07323, -100.54688, "North America", "L", 6255149]
places.loc[places["word"]=="Atlantic Ocean",geocolumns] = ["OCN", 10, -25, "Atlantic Ocean", "H", 3373405]
places.loc[places["word"]=="Scandinavia",geocolumns] = ["RGN", 63, 12, "Scandinavia", "L", 2614165]
places.loc[places["word"]=="California (USA",geocolumns] = ["ADM1", 37.25022, -119.75126, "California", "A", 5332921]
places.loc[places["word"]=="California, USA",geocolumns] = ["ADM1", 37.25022, -119.75126, "California", "A", 5332921]
places.loc[places["word"]=="North Pacific",geocolumns] = ["OCN", 30, -170, "North Pacific Ocean", "H", 4030875]
places.loc[places["word"]=="Huai",geocolumns] = ["STM", 33.133333, 118.5, "Huai He", "H", 1807690]
places.loc[places["word"]=="Washington, DC",geocolumns] = ["PPLC", 38.89511, -77.03637, "Washington", "P", 4140963]
places.loc[places["word"]=="Messinian",geocolumns] = ["ADM2", 37.25, -21.83333, "Nomos Messinias", "A", 257149]
places.loc[places["word"]=="Ionian Sea",geocolumns] = ["SEA", 39, 19, "Ionian Sea", "H", 2463713]
places.loc[places["word"]=="NYC",geocolumns] = ["PPL", 40.71427, -74.00597, "New York City", "P", 5128581]
places.loc[places["word"]=="Indian Ocean",geocolumns] = ["OCN", -10, 70, "Indian Ocean", "H", 1545739]
places.loc[places["word"]=="North Sea",geocolumns] = ["SEA", 55, 3, "North Sea", "H", 2960848]
places.loc[places["word"]=="Philippine Sea",geocolumns] = ["SEA", 20, 135, "Philippine Sea", "H", 1818190]
places.loc[places["word"]=="Black Sea",geocolumns] = ["SEA", 43, 34, "Black Sea", "H", 630673]
places.loc[places["word"]=="Coral Sea",geocolumns] = ["SEA", -20, 155, "Coral Sea", "H", 2194166]
places.loc[places["word"]=="Timor Sea",geocolumns] = ["SEA", -11, 127, "Timor Sea", "H", 2078065]
places.loc[places["word"]=="Hudson Bay",geocolumns] = ["BAY", 60, -85, "Hudson Bay", "H", 5978134]
places.loc[places["word"]=="Bering Sea",geocolumns] = ["SEA", 60, -175, "Bering Sea", "H", 4031788]
places.loc[places["word"]=="Okhotsk Sea",geocolumns] = ["SEA", 55, 150, "Sea of Okhotsk", "H", 2127380]


places.loc[places["place_name"]=="Central Upper Nile",geocolumns] = ["ADM1", 10, 32.7, "Upper Nile", "A", 381229]
places.loc[places["place_name"]=="Gobolka Woqooyi Galbeed","place_name"] = "Woqooyi Galbeed"



places = places[places["place_name"]!="Pacific County"]
places = places.loc[places["word"]!="B.V."]
places = places[places["word"]!="MMT"]
places = places[places["word"]!="Yellow"]
places = places[places["word"]!="Western North"]
places = places[places["word"]!="colonies"]
places = places[places["word"]!="TN"]
places = places[places["word"]!="NH"]
places = places[places["word"]!="Mn"]
places = places[places["word"]!="Tx"]
places = places[places["word"]!="TX"]
places = places[places["word"]!="Tn"]
places = places[places["word"]!="FL"]
places = places[places["word"]!="Spartina"]
places = places[places["word"]!="Tamarix"]
places = places[places["word"]!="Eurasia"]
places = places[places["word"]!="Phillyrea"]
places = places[places["word"]!="N-15"]
places = places[places["word"]!="LT50"]
places = places[places["word"]!="POSEIDON"]
places = places[places["word"]!="LC50"]
places = places[places["word"]!="El Nio"]
places = places[places["word"]!="La Nia"]
places = places[places["word"]!="Red"]
places = places[places["word"].str.len()>2]
places = places[places["word"]!="Gulf Stream"]

places.lat = places.lat.astype(float)
places.lon = places.lon.astype(float)

places = places.drop_duplicates(["doc_id","word"])

print(places.shape)

places.to_csv("../data/place_df.csv",index=False)
#places.to_csv("~/ownCloud/regional-impacts-data/place_df.csv",index=False)
# Out:
# (148899, 13)

# %%
places
# Out:
#                  word                           spans country_predicted  \
# 2         Barents Sea    [{'start': 329, 'end': 340}]               NaN
# 9        East Siberia  [{'start': 1228, 'end': 1240}]               NaN
# 17         Gulf Coast    [{'start': 497, 'end': 507}]               USA
# 19          San Diego    [{'start': 114, 'end': 123}]               USA
# 29             Alaska      [{'start': 91, 'end': 97}]               USA
# ...               ...                             ...               ...
# 94390  Gulf of Mexico                             NaN               NaN
# 94766  Gulf of Mexico                             NaN               NaN
# 94837  Gulf of Mexico                             NaN               NaN
# 95156  Gulf of Mexico                             NaN               NaN
# 95740  Gulf of Mexico                             NaN               NaN
#
#        country_conf   doc_id       admin1       lat        lon country_code3  \
# 2          0.904877  1340101          NaN  74.00000   36.00000           NaN
# 9          0.904877  1340101          NaN  74.00000  166.00000           NaN
# 17         0.904877   222401  Mississippi  29.36901  -95.00565           USA
# 19         0.963741  3307272   California  33.02820 -116.77021           USA
# 29         0.959621   355004       Alaska  64.00028 -150.00028           USA
# ...             ...      ...          ...       ...        ...           ...
# 94390      0.800000  1442314          NaN  25.00000  -90.00000           NaN
# 94766      0.800000    32313          NaN  25.00000  -90.00000           NaN
# 94837      0.800000  1288986          NaN  25.00000  -90.00000           NaN
# 95156      0.800000  1360432          NaN  25.00000  -90.00000           NaN
# 95740      0.800000   416377          NaN  25.00000  -90.00000           NaN
#
#        geonameid         place_name feature_class feature_code
# 2       630674.0        Barents Sea             H          SEA
# 9      2127381.0  East Siberian Sea             H          SEA
# 17     7287689.0         Gulf Coast             L         AREA
# 19     5391832.0   San Diego County             A         ADM2
# 29     5879092.0             Alaska             A         ADM1
# ...          ...                ...           ...          ...
# 94390  3523271.0     Gulf of Mexico             H         GULF
# 94766  3523271.0     Gulf of Mexico             H         GULF
# 94837  3523271.0     Gulf of Mexico             H         GULF
# 95156  3523271.0     Gulf of Mexico             H         GULF
# 95740  3523271.0     Gulf of Mexico             H         GULF
#
# [148694 rows x 13 columns]

# %%
places[places["place_name"].str.contains("Gulf")].groupby('word').size().sort_values(ascending=False).head(20)
# Out:
# word
# Gulf of Mexico            478
# Gulf Coast                 75
# Persian Gulf               58
# Arabian Gulf               26
# Gulf of Maine              16
# Gulf                       15
# Gulf coast                 15
# Gulf of California         14
# western Gulf               10
# Amundsen Gulf               9
# Gulf Coasts                 7
# Beibu Gulf                  7
# Gulf of Alaska              6
# Gulf of Aden                5
# US Gulf Coast               4
# Gulf of Carpentaria         4
# Gulf of the Farallones      4
# Gulf of Guinea              4
# Florida Gulf                3
# Exmouth Gulf                3
# dtype: int64

# %%
places[places["word"].str.lower().str.contains("solomon")]
# Out:
#                        word                           spans country_predicted  \
# 2984        Solomon Islands    [{'start': 106, 'end': 121}]               SLB
# 12091    San Solomon Spring    [{'start': 211, 'end': 229}]               USA
# 12096   San Solomon Springs  [{'start': 1334, 'end': 1353}]               USA
# 29447       Solomon Islands    [{'start': 119, 'end': 134}]               SLB
# 45112       Solomon Islands    [{'start': 209, 'end': 224}]               SLB
# 71193       Solomon Islands  [{'start': 1057, 'end': 1072}]               SLB
# 85276       Solomon Islands    [{'start': 409, 'end': 424}]               SLB
# 105656      Solomon Islands    [{'start': 779, 'end': 794}]               SLB
# 136136      Solomon islands    [{'start': 103, 'end': 118}]               SLB
# 158567      Solomon Islands      [{'start': 81, 'end': 96}]               SLB
# 166046      Solomon Islands    [{'start': 943, 'end': 958}]               SLB
# 168064      Solomon Islands     [{'start': 94, 'end': 109}]               SLB
# 172010      Solomon Islands    [{'start': 134, 'end': 149}]               SLB
# 175560      SOLOMON-ISLANDS    [{'start': 102, 'end': 117}]               SLB
# 268458      Solomon Islands    [{'start': 515, 'end': 530}]               SLB
# 270479      Solomon Islands    [{'start': 292, 'end': 307}]               SLB
# 270542      Solomon Islands    [{'start': 777, 'end': 792}]               SLB
# 272481      Solomon Islands    [{'start': 353, 'end': 368}]               SLB
# 284786      Solomon Islands     [{'start': 91, 'end': 106}]               SLB
# 308529      Solomon Islands    [{'start': 504, 'end': 519}]               SLB
# 316169      Solomon Islands    [{'start': 401, 'end': 416}]               SLB
# 332475      Solomon Islands    [{'start': 650, 'end': 665}]               SLB
# 360137      Solomon Islands    [{'start': 394, 'end': 409}]               SLB
# 380602      Solomon Islands      [{'start': 61, 'end': 76}]               SLB
# 398282      Solomon Islands    [{'start': 968, 'end': 983}]               SLB
#
#         country_conf   doc_id admin1       lat        lon country_code3  \
# 2984        0.946707  1467932    NaN  -8.00000  159.00000           SLB
# 12091       0.948191  2320338  Texas  30.94431 -103.78852           USA
# 12096       0.948191  2320338  Texas  30.94431 -103.78852           USA
# 29447       0.946458  1432549    NaN  -8.00000  159.00000           SLB
# 45112       0.946707  2316389    NaN  -8.00000  159.00000           SLB
# 71193       0.938801   185982    NaN  -8.00000  159.00000           SLB
# 85276       0.954475   255058    NaN  -8.00000  159.00000           SLB
# 105656      0.953179  3296073    NaN  -8.00000  159.00000           SLB
# 136136      0.963741  2309534    NaN  -8.00000  159.00000           SLB
# 158567      0.948191   739225    NaN  -8.00000  159.00000           SLB
# 166046      0.928841  2325454    NaN  -8.00000  159.00000           SLB
# 168064      0.948191   140937    NaN  -8.00000  159.00000           SLB
# 172010      0.954475   818218    NaN  -8.00000  159.00000           SLB
# 175560      0.963741  3308334    NaN  -8.00000  159.00000           SLB
# 268458      0.945330   664946    NaN  -8.00000  159.00000           SLB
# 270479      0.953179  2344039    NaN  -8.00000  159.00000           SLB
# 270542      0.946707    25547    NaN  -8.00000  159.00000           SLB
# 272481      0.951695    16813    NaN  -8.00000  159.00000           SLB
# 284786      0.948191   770459    NaN  -8.00000  159.00000           SLB
# 308529      0.951695   453144    NaN  -8.00000  159.00000           SLB
# 316169      0.948191   381102    NaN  -8.00000  159.00000           SLB
# 332475      0.951695   584777    NaN  -8.00000  159.00000           SLB
# 360137      0.951695  2318301    NaN  -8.00000  159.00000           SLB
# 380602      0.946707  3828464    NaN  -8.00000  159.00000           SLB
# 398282      0.948191  3791945    NaN  -8.00000  159.00000           SLB
#
#         geonameid          place_name feature_class feature_code
# 2984    2103350.0     Solomon Islands             A         PCLI
# 12091   5530122.0  San Solomon Spring             H         SPNG
# 12096   5530122.0  San Solomon Spring             H         SPNG
# 29447   2103350.0     Solomon Islands             A         PCLI
# 45112   2103350.0     Solomon Islands             A         PCLI
# 71193   2103350.0     Solomon Islands             A         PCLI
# 85276   2103350.0     Solomon Islands             A         PCLI
# 105656  2103350.0     Solomon Islands             A         PCLI
# 136136  2103350.0     Solomon Islands             A         PCLI
# 158567  2103350.0     Solomon Islands             A         PCLI
# 166046  2103350.0     Solomon Islands             A         PCLI
# 168064  2103350.0     Solomon Islands             A         PCLI
# 172010  2103350.0     Solomon Islands             A         PCLI
# 175560  2103350.0     Solomon Islands             A         PCLI
# 268458  2103350.0     Solomon Islands             A         PCLI
# 270479  2103350.0     Solomon Islands             A         PCLI
# 270542  2103350.0     Solomon Islands             A         PCLI
# 272481  2103350.0     Solomon Islands             A         PCLI
# 284786  2103350.0     Solomon Islands             A         PCLI
# 308529  2103350.0     Solomon Islands             A         PCLI
# 316169  2103350.0     Solomon Islands             A         PCLI
# 332475  2103350.0     Solomon Islands             A         PCLI
# 360137  2103350.0     Solomon Islands             A         PCLI
# 380602  2103350.0     Solomon Islands             A         PCLI
# 398282  2103350.0     Solomon Islands             A         PCLI

# %%
did = 28635
print(df[df.id==did].content.values[0])
for i, r in places[places["doc_id"]==did].iterrows():
    print(r["word"],r["place_name"],r["feature_code"],r["country_conf"])

# %%
places.head()

# %%
import pycountry_convert as pc
def get_cont(x):
    continents = {
        'NA': 'North America',
        'SA': 'South America', 
        'AS': 'Asia',
        'OC': 'Oceania',
        'AF': 'Africa',
        'EU': 'Europe'
    }
    try:
        return continents[pc.country_alpha2_to_continent_code(pc.country_alpha3_to_country_alpha2(x['country_predicted']))]
    except:
        return None
places['continent'] = places.apply(lambda x: get_cont(x), axis=1)
other_country_continents = [
    ("ESH","Africa"),
    ("TLS","Oceania"),
    ("XKX","Europe")
    
]
for country,continent in other_country_continents:
    places.loc[places['country_predicted']==country,"continent"] = continent

places.head()
# Out:
#             word                           spans country_predicted  \
# 2    Barents Sea    [{'start': 329, 'end': 340}]               NaN
# 9   East Siberia  [{'start': 1228, 'end': 1240}]               NaN
# 17    Gulf Coast    [{'start': 497, 'end': 507}]               USA
# 19     San Diego    [{'start': 114, 'end': 123}]               USA
# 29        Alaska      [{'start': 91, 'end': 97}]               USA
#
#     country_conf   doc_id       admin1       lat        lon country_code3  \
# 2       0.904877  1340101          NaN  74.00000   36.00000           NaN
# 9       0.904877  1340101          NaN  74.00000  166.00000           NaN
# 17      0.904877   222401  Mississippi  29.36901  -95.00565           USA
# 19      0.963741  3307272   California  33.02820 -116.77021           USA
# 29      0.959621   355004       Alaska  64.00028 -150.00028           USA
#
#     geonameid         place_name feature_class feature_code      continent
# 2    630674.0        Barents Sea             H          SEA           None
# 9   2127381.0  East Siberian Sea             H          SEA           None
# 17  7287689.0         Gulf Coast             L         AREA  North America
# 19  5391832.0   San Diego County             A         ADM2  North America
# 29  5879092.0             Alaska             A         ADM1  North America

# %%
doc_continents = places[["doc_id","continent"]]
print(doc_continents.shape)
doc_continents = doc_continents.drop_duplicates(["doc_id","continent"])
print(doc_continents.shape)
doc_continents.to_csv('../data/doc_continents.csv',index=False)
# Out:
# (124420, 2)
# (80356, 2)
