# %%
import pandas as pd
from mordecai import Geoparser
import re

# %%
# Get a list of predictions for the unseen documents
relevance = pd.read_csv('../data/1_document_relevance.csv')
relevance.head()
# Out:
#         id  0 - relevance - mean_prediction  0 - relevance - std_prediction  \
# 0  3921033                         0.262942                        0.019405
# 1  2351389                         0.065476                        0.009918
# 2  1686287                         0.040167                        0.010916
# 3  1310127                         0.320405                        0.035234
# 4  1890786                         0.774876                        0.019936
#
#    0 - relevance - lower_pred  0 - relevance - upper_pred
# 0                    0.243536                    0.282347
# 1                    0.055558                    0.075394
# 2                    0.029250                    0.051083
# 3                    0.285171                    0.355639
# 4                    0.754940                    0.794812

# %%
# Get a dataframe of seen and unseen documents and their titles and abstracts

cols = ["id","content","title","relevant"]
seen_df = pd.read_csv('../data/0_labelled_documents.csv')[cols]
unseen_df = pd.read_csv('../data/0_unlabelled_documents.csv')[cols]

df = (pd.concat([seen_df,unseen_df])
      .sort_values('id')
      .sample(frac=1, random_state=1)
      .reset_index(drop=True)
).merge(relevance, how="left")
print(df.shape)
df.head()
# Out:
# /home/galm/software/mordecai-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (600690, 8)
#         id                                            content  \
# 0  3921033  Recovery of phytosterol from roselle (Hibiscus...
# 1  2351389  Science denialism retards evidenced-based poli...
# 2  1686287  The QuikSCAT mission provided valuable daily i...
# 3  1310127  This paper is to promote a further understandi...
# 4  1890786  Instrumental climate records are too short to ...
#
#                                                title  relevant  \
# 0  Optimization of supercritical fluid extraction...       0.0
# 1       On allegations of invasive species denialism       0.0
# 2  Wind characteristics in the North and Baltic S...       0.0
# 3  The interdecadal variations of the summer mons...       0.0
# 4                          Corals as climate archive       0.0
#
#    0 - relevance - mean_prediction  0 - relevance - std_prediction  \
# 0                         0.262942                        0.019405
# 1                         0.065476                        0.009918
# 2                         0.040167                        0.010916
# 3                         0.320405                        0.035234
# 4                         0.774876                        0.019936
#
#    0 - relevance - lower_pred  0 - relevance - upper_pred
# 0                    0.243536                    0.282347
# 1                    0.055558                    0.075394
# 2                    0.029250                    0.051083
# 3                    0.285171                    0.355639
# 4                    0.754940                    0.794812

# %%
# Filter out those that are potentially relevant or relevant
df = df[
    (df["0 - relevance - upper_pred"]>=0.5) | 
    (df["relevant"]==1)
]
print(df.shape)
df.head()
# Out:
# (119292, 8)
#          id                                            content  \
# 4   1890786  Instrumental climate records are too short to ...
# 16   715550  Environmentally induced change appears to be i...
# 22  3827381  How human activities have altered hydrological...
# 35   680654  We tested for competition between pink salmon ...
# 37   214441  We conducted a night-time warming and drought ...
#
#                                                 title  relevant  \
# 4                           Corals as climate archive       0.0
# 16  Recruitment in a changing environment: the 200...       0.0
# 22  Contrasting Influences of Human Activities on ...       0.0
# 35  Survival of Puget Sound chinook salmon (Oncorh...       0.0
# 37  Effects of long-term experimental night-time w...       0.0
#
#     0 - relevance - mean_prediction  0 - relevance - std_prediction  \
# 4                          0.774876                        0.019936
# 16                         0.774296                        0.040719
# 22                         0.693427                        0.050493
# 35                         0.386028                        0.121225
# 37                         0.905650                        0.008319
#
#     0 - relevance - lower_pred  0 - relevance - upper_pred
# 4                     0.754940                    0.794812
# 16                    0.733576                    0.815015
# 22                    0.642935                    0.743920
# 35                    0.264803                    0.507253
# 37                    0.897332                    0.913969

# %%
# Either get old data or make a new dataframe
try:
    processed_places = pd.read_csv('../data/places.csv')
    df = df[~df['id'].isin(processed_places['doc_id'])]
except:
    processed_places = pd.DataFrame()
    
df.shape
# Out:
# (46935, 8)

# %%
# Test the geoparser
geo = Geoparser()
geo.geoparse("I took the tube from Oxford Circus to London Bridge, via Bank")
# Out:
# Models path: /home/galm/software/mordecai-env/lib/python3.8/site-packages/mordecai/models/
# [{'word': 'Oxford Circus',
#   'spans': [{'start': 21, 'end': 34}],
#   'country_predicted': 'GBR',
#   'country_conf': 0.96374094,
#   'geo': {'admin1': 'England',
#    'lat': '51.51517',
#    'lon': '-0.14181',
#    'country_code3': 'GBR',
#    'geonameid': '2640727',
#    'place_name': 'Oxford Circus Underground Station',
#    'feature_class': 'S',
#    'feature_code': 'MTRO'}},
#  {'word': 'London Bridge',
#   'spans': [{'start': 38, 'end': 51}],
#   'country_predicted': 'GBR',
#   'country_conf': 0.96374094,
#   'geo': {'admin1': 'England',
#    'lat': '51.50821',
#    'lon': '-0.08763',
#    'country_code3': 'GBR',
#    'geonameid': '6619889',
#    'place_name': 'London Bridge',
#    'feature_class': 'S',
#    'feature_code': 'BDG'}}]

# %%
# %%capture 
places = []
geos = []

# Go through the rows of the dataframe
for i, row in df.iterrows():
    
    # Get the text we want to geoparse, join title and abstract, get rid of copyright stuff
    t = row['title'] + " " + row['content']
    t = t.split("Copyright (C)")[0] 
    t = re.split("\([C-c]\) [1-2][0-9]{3} Elsevier",t)[0] 
    t = t.split("Published by Elsevier")[0] 
    t = t.split("Copyright. (C)")[0] 
    t = re.split("\. \(C\) [1-2][0-9]{3} ",t)[0] 
    t = re.split("\. \(C\) Copyright",t)[0]   
    
    # geoparse
    gp = geo.geoparse(t)
    
    rplaces = []
    continent = None
    for p in gp:
        try:
            a2 = country_alpha3_to_country_alpha2(p["country_predicted"])
            continent = country_alpha2_to_continent_code(a2)
        except:
            pass
        if "geo" in p:
            try:
                a2 = country_alpha3_to_country_alpha2(p["geo"]["country_code3"])
                continent = country_alpha2_to_continent_code(a2)
            except:
                pass
            for key, value in p["geo"].items():
                p[key] = value
            del p["geo"]
            
        p["doc_id"] = row["id"]
            
        rplaces.append(p)
        places.append(p)
    df.loc[i,"continent"] = continent
    df.loc[i,"places"] = len(rplaces)

# %%
# Merge all the data together
combined_place_df = processed_places.append(pd.DataFrame.from_dict(places))
print(combined_place_df.shape)
combined_place_df.to_csv("../data/places.csv", index=False)
combined_place_df.tail()
# Out:
# (539267, 13)
#                  word                           spans country_predicted  \
# 135419        Daphnia    [{'start': 341, 'end': 348}]               USA
# 135420           Vtg1    [{'start': 881, 'end': 885}]               VNM
# 135421  South America    [{'start': 898, 'end': 911}]                NA
# 135422  Dolphin Gulls  [{'start': 1140, 'end': 1153}]               CYM
# 135423       Malvinas  [{'start': 1186, 'end': 1194}]               ARG
#
#         country_conf   doc_id           admin1        lat         lon  \
# 135419      0.904877  3630234          Wyoming   44.95516  -109.47165
# 135420      0.922130  3630234  Bà Rịa-Vũng Tàu   10.34599   107.08426
# 135421      0.904877  3892528               NA  -14.60485   -57.65625
# 135422      0.248213  3892528              NaN        NaN         NaN
# 135423      0.283659  3892528              NaN        NaN         NaN
#
#        country_code3 geonameid     place_name feature_class feature_code
# 135419           USA   5822652   Daphnia Lake             H           LK
# 135420           VNM   1562414       Vũng Tàu             P          PPL
# 135421            NA   6255150  South America             L         CONT
# 135422           NaN       NaN            NaN           NaN          NaN
# 135423           NaN       NaN            NaN           NaN          NaN
