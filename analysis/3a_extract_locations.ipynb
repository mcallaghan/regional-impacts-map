# %%
import django, sys, os
sys.path.append('/home/max/software/django-tmv/tmv_mcc-apsis/BasicBrowser')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "BasicBrowser.settings")
django.setup()

from scoping.models import *
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from itertools import product, combinations
from utils.text import *
from pycountry_convert import  country_alpha2_to_continent_code, country_alpha3_to_country_alpha2

import pandas as pd

# %%
for x in df.columns:
    print(x)
# Out:
# Unnamed: 0
# id
# content
# title
# wosarticle__de
# wosarticle__wc
# ar5
# seen
# relevant
# 12 - Coastal and marine Ecosystems
# 12 - Human and managed
# 12 - Mountains, snow and ice
# 12 - Rivers, lakes, and soil moisture
# 12 - Terrestrial ES
# 10 - places
# 11 - Africa
# 11 - Asia
# 11 - Australasia
# 11 - Central & South America
# 11 - Europe
# 11 - Global
# 11 - North America
# 11 - Open ocean
# 11 - Polar Regions
# 11 - Small Islands
# 13 - Coastal erosion and/or sea level effects
# 13 - Food production
# 13 - Glaciers, snow, ice and/or permafrost
# 13 - Livelihoods, health and/or economics
# 13 - Marine ecosystems
# 13 - Rivers, lakes, floods and/or drought
# 13 - Terrestrial ecosystems
# 13 - Wildfire
# 14 - Coastal human systems
# 14 - Cryosphere
# 14 - Droughts
# 14 - Marine (eco-)systems
# 14 - River floods
# 14 - Terrestrial (eco-)systems
# 15 - 01. Extreme water levels
# 15 - 02. Sea ice retreat
# 15 - 03. Glacier retreat
# 15 - 04. Changes in strong precipitation
# 15 - 05. Shifts in phenology (ocean)
# 15 - 06. Geographical shift in fish species
# 15 - 07. Changes in warm water corals
# 15 - 08. Species metabolism
# 15 - 09. Species distribution (land)
# 15 - 10. Shifts in phenology (land)
# 15 - 11. Wildfires
# 15 - 12. Drought frequency and intensity
# 15 - 13. River floods
# 15 - 14. Crop yields
# 15 - 15. Coastal human systems
# 15 - 21. Health
# 15 - Arctic infrastructure
# 15 - River runoff
# 15 - Seagrass
# 16 - Climate Impact attribution
# 16 - Climate attribution
# 16 - Climate event attribution
# 16 - Experimental evidence
# 16 - Future/modelled impacts
# 16 - Impact event attribution
# 16 - No Climate Impact attribution
# 16 - Unclear
# 16 - Weather sensitivity
# 2 - 2.1. Climate change attribution
# 2 - 2.2 Trend attribution
# 2 - 2.3. Attribution to extreme event
# 2 - 2.3. Impact trend attribution<hidden>
# 2 - 2.4. Sensitivity
# 2 - 2.5. Detection of a regional climate trend (no attribution)
# 2 - 2.6. Null results
# 3 - 3.1. Physical systems
# 3 - 3.2. Biological systems
# 3 - 3.3. Human and managed systems
# 4 - 01 CO2 concentration
# 4 - 02 Air or land surface temperature changes
# 4 - 03 Extreme temperature
# 4 - 04 Radiation
# 4 - 05 Changes in precipitation
# 4 - 06 Humidity
# 4 - 07 Aridity/dryness
# 4 - 08 Changes in strong precipitation
# 4 - 09 Atmospheric/marine circulation or teleconnections
# 4 - 10 Wind speed
# 4 - 12 Seasonality
# 4 - 13 Other (physical systems)
# 4 - 14 Sea level change
# 4 - 16 Sea surface temperature
# 4 - 17 Ocean acidification
# 4 - 19 Water quality/chemistry (oceans)
# 4 - 21 Water temperature (freshwater)
# 4 - 22 Water quality/chemistry (freshwater)
# 4 - 23 Soil moisture
# 4 - 24 Water level (lake, reservoir, groundwater)
# 4 - 25 Evapotranspiration
# 4 - 26 Drought frequency and intensity
# 4 - 27 River floods
# 4 - 28 River runoff
# 4 - 29 Other (Rivers, lakes and soil moisture)
# 4 - 30 Snow
# 4 - 31 Landslides/instability
# 4 - 32 Permafrost
# 4 - 33 Sea ice retreat
# 4 - 34 Glacier retreat
# 4 - 36 Species distribution (marine & coastal)
# 4 - 37 Shifts in phenology (marine & coastal)
# 4 - 38 Geographical shift  (marine & coastal)
# 4 - 39 Changes in fisheries output/catch (potential)
# 4 - 40 Changes in warm water corals
# 4 - 41 Species metabolism (marine & coastal)
# 4 - 42 Species abundance (marine & coastal)
# 4 - 43 Biome shift (marine & coastal)
# 4 - 44 Biodiversity effects (marine & coastal)
# 4 - 45 Ocean ecosystem productivity
# 4 - 46 Changes in kelp forests
# 4 - 47 Seagrass
# 4 - 48 Carbon cycle (marine & coastal)
# 4 - 48 Species distribution (Terrestrial and freshwater)<hidden>
# 4 - 51 Distribution and range shifts (Terrestrial and freshwater)
# 4 - 52 Shifts in phenology (Terrestrial and freshwater)
# 4 - 52 Species abundance (Terrestrial and freshwater)<hidden>
# 4 - 53 Mortality and growth
# 4 - 54 Physiology and metabolism
# 4 - 55 Community composition and interaction
# 4 - 56 Terrestrial carbon cycle
# 4 - 57 Biogeochemical flows (Terrestrial and freshwater)
# 4 - 58 Biodiversity effects (Terrestrial and freshwater)<hidden>
# 4 - 58 Biome shift (Terrestrial and freshwater)<hidden>
# 4 - 58 Carbon flux (Terrestrial and freshwater)<hidden>
# 4 - 58 Ecosystem productivity (Terrestrial and freshwater)<hidden>
# 4 - 58 Geographical shift  (Terrestrial and freshwater)<hidden>
# 4 - 58 Pests and diseases
# 4 - 58 Species metabolism (Terrestrial and freshwater)<hidden>
# 4 - 58 Vegetation<hidden>
# 4 - 59 Wildfires
# 4 - 60 Other (Terrestrial and freshwater)
# 4 - 61 Arctic infrastructure
# 4 - 62 Coastal human systems
# 4 - 63 Human Settlements
# 4 - 64 Indigenous communities
# 4 - 65 Gender specific / gender unequal impacts
# 4 - 66 Health
# 4 - 67 Vector-borne diseases
# 4 - 68 Extreme heat exposure
# 4 - 69 Crop yields
# 4 - 70 Food prices
# 4 - 71 Malnutrition
# 4 - 72 Conflict
# 4 - 73 Displacement and migration
# 4 - 75 Economic activity
# 4 - 76 Human water use
# 4 - 77 Land use change
# 4 - 78 Land management
# 4 - 79 Livestock health
# 4 - 80 Livestock management
# 4 - 81 Other (human and managed systems)
# 5 - 5.1. Physical systems
# 5 - 5.2. Biological systems
# 5 - 5.3. Human and managed systems
# 6 - 01 CO2 concentration
# 6 - 02 Air or land surface temperature changes
# 6 - 03 Extreme temperature
# 6 - 04 Radiation
# 6 - 05 Changes in precipitation
# 6 - 06 Humidity
# 6 - 07 Aridity/dryness
# 6 - 08 Changes in strong precipitation
# 6 - 09 Atmospheric/marine circulation or teleconnections
# 6 - 10 Wind speed
# 6 - 11 Storms
# 6 - 12 Seasonality
# 6 - 14 Sea level change
# 6 - 16 Sea surface temperature
# 6 - 17 Ocean acidification
# 6 - 18 Oxygen content
# 6 - 19 Water quality/chemistry (oceans)
# 6 - 21 Water temperature (freshwater)
# 6 - 22 Water quality/chemistry (freshwater)
# 6 - 23 Soil moisture
# 6 - 24 Water level (lake, reservoir, groundwater)
# 6 - 25 Evapotranspiration
# 6 - 26 Drought frequency and intensity
# 6 - 27 River floods
# 6 - 28 River runoff
# 6 - 29 Other (Rivers, lakes and soil moisture)
# 6 - 30 Snow
# 6 - 31 Landslides/instability
# 6 - 32 Permafrost
# 6 - 33 Sea ice retreat
# 6 - 34 Glacier retreat
# 6 - 35 Other (mountains, snow and ice)
# 6 - 36 Species distribution (marine & coastal)
# 6 - 38 Geographical shift  (marine & coastal)
# 6 - 40 Changes in warm water corals
# 6 - 42 Species abundance (marine & coastal)
# 6 - 47 Seagrass
# 6 - 51 Distribution and range shifts (Terrestrial and freshwater)
# 6 - 52 Shifts in phenology (Terrestrial and freshwater)
# 6 - 52 Species abundance (Terrestrial and freshwater)<hidden>
# 6 - 53 Mortality and growth
# 6 - 54 Physiology and metabolism
# 6 - 55 Community composition and interaction
# 6 - 56 Terrestrial carbon cycle
# 6 - 58 Ecosystem productivity (Terrestrial and freshwater)<hidden>
# 6 - 58 Pests and diseases
# 6 - 59 Wildfires
# 6 - 60 Other (Terrestrial and freshwater)
# 6 - 63 Human Settlements
# 6 - 65 Gender specific / gender unequal impacts
# 6 - 66 Health
# 6 - 67 Vector-borne diseases
# 6 - 69 Crop yields
# 6 - 70 Food prices
# 6 - 72 Conflict
# 6 - 73 Displacement and migration
# 6 - 75 Economic activity
# 6 - 76 Human water use
# 6 - 77 Land use change
# 6 - 78 Land management
# 6 - 80 Livestock management
# 7 - 7.1. Observational evidence
# 7 - 7.2. Modelling evidence
# 7 - 7.3. Experimental evidence
# 8 - 8.01. Quantitative
# 8 - 8.02. Quantitative - meta analyses
# 8 - 8.03. Quantitative - process-based modelling
# 8 - 8.04. Quantitative - empirical models
# 8 - 8.05. Quantitative - statistical
# 8 - 8.06. Qualitative - literature review
# 8 - 8.07. Qualitative - expert interviews
# 8 - 8.08. Qualitative - household surveys
# 8 - 8.09. Mixed methods
# 8 - 8.10. Case studies
# 8 - 8.11. Remote sensing
# 9 - observations
# 12 - Physical systems
# 12 - Mountains, snow and ice - k_prediction
# 12 - Mountains, snow and ice - k_prediction_binary
# 12 - Rivers, lakes, and soil moisture - k_prediction
# 12 - Rivers, lakes, and soil moisture - k_prediction_binary
# 12 - Coastal and marine Ecosystems - k_prediction
# 12 - Coastal and marine Ecosystems - k_prediction_binary
# 12 - Terrestrial ES - k_prediction
# 12 - Terrestrial ES - k_prediction_binary
# 12 - Human and managed - k_prediction
# 12 - Human and managed - k_prediction_binary
# 12 - Physical systems - k_prediction
# 12 - Physical systems - k_prediction_binary
# 12 - Mountains, snow and ice - mean_prediction
# 12 - Mountains, snow and ice - std_prediction
# 12 - Mountains, snow and ice - lower_pred
# 12 - Mountains, snow and ice - upper_pred
# 12 - Rivers, lakes, and soil moisture - mean_prediction
# 12 - Rivers, lakes, and soil moisture - std_prediction
# 12 - Rivers, lakes, and soil moisture - lower_pred
# 12 - Rivers, lakes, and soil moisture - upper_pred
# 12 - Coastal and marine Ecosystems - mean_prediction
# 12 - Coastal and marine Ecosystems - std_prediction
# 12 - Coastal and marine Ecosystems - lower_pred
# 12 - Coastal and marine Ecosystems - upper_pred
# 12 - Terrestrial ES - mean_prediction
# 12 - Terrestrial ES - std_prediction
# 12 - Terrestrial ES - lower_pred
# 12 - Terrestrial ES - upper_pred
# 12 - Human and managed - mean_prediction
# 12 - Human and managed - std_prediction
# 12 - Human and managed - lower_pred
# 12 - Human and managed - upper_pred
# 2 - Trend or climate change attribtion
# 2 - Trend or climate change attribtion - k_prediction
# 2 - Trend or climate change attribtion - k_prediction_binary
# 2 - 2.4. Sensitivity - k_prediction
# 2 - 2.4. Sensitivity - k_prediction_binary
# 2 - 2.5. Detection of a regional climate trend (no attribution) - k_prediction
# 2 - 2.5. Detection of a regional climate trend (no attribution) - k_prediction_binary
# 2 - Trend or climate change attribtion - mean_prediction
# 2 - Trend or climate change attribtion - std_prediction
# 2 - Trend or climate change attribtion - lower_pred
# 2 - Trend or climate change attribtion - upper_pred
# 2 - 2.4. Sensitivity - mean_prediction
# 2 - 2.4. Sensitivity - std_prediction
# 2 - 2.4. Sensitivity - lower_pred
# 2 - 2.4. Sensitivity - upper_pred
# 2 - 2.5. Detection of a regional climate trend (no attribution) - mean_prediction
# 2 - 2.5. Detection of a regional climate trend (no attribution) - std_prediction
# 2 - 2.5. Detection of a regional climate trend (no attribution) - lower_pred
# 2 - 2.5. Detection of a regional climate trend (no attribution) - upper_pred
# PY
# 6 - 13 Other (physical systems)
# ca_rated
# 6 - No drivers
# 6 - Precipitation
# Human drivers
# 6 - Human drivers
# 6 - Temperature
# 6 - Water availability
# 6 - None/Other
# 6 - Temperature - k_prediction
# 6 - Temperature - k_prediction_binary
# 6 - Precipitation - k_prediction
# 6 - Precipitation - k_prediction_binary
# 6 - 30 Snow - k_prediction
# 6 - 30 Snow - k_prediction_binary
# 6 - Human drivers - k_prediction
# 6 - Human drivers - k_prediction_binary
# 6 - Water availability - k_prediction
# 6 - Water availability - k_prediction_binary
# 6 - Temperature - mean_prediction
# 6 - Temperature - std_prediction
# 6 - Temperature - lower_pred
# 6 - Temperature - upper_pred
# 6 - Precipitation - mean_prediction
# 6 - Precipitation - std_prediction
# 6 - Precipitation - lower_pred
# 6 - Precipitation - upper_pred

# %%
df = pd.read_csv('../data/category_predictions.csv')
df = df.query('upper_pred>0.5')
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/collections/__init__.py in __getitem__(self, key)
#     882                 pass
# --> 883         return self.__missing__(key)            # support subclasses that define __missing__
#     884
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/collections/__init__.py in __missing__(self, key)
#     874     def __missing__(self, key):
# --> 875         raise KeyError(key)
#     876
#
# KeyError: 'upper_pred'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     197                 # e.g., df[df > 0]
# --> 198                 return self.temps[key]
#     199             except KeyError:
#
# KeyError: 'upper_pred'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-3-13cec905cbd3> in <module>()
#       1 df = pd.read_csv('../data/category_predictions.csv')
# ----> 2 df = df.query('upper_pred>0.5')
#       3 print(df.shape)
#       4 df.head()
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3229         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3230         kwargs["target"] = None
# -> 3231         res = self.eval(expr, **kwargs)
#    3232
#    3233         try:
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3344         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3345
# -> 3346         return _eval(expr, inplace=inplace, **kwargs)
#    3347
#    3348     def select_dtypes(self, include=None, exclude=None) -> "DataFrame":
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     330         )
#     331
# --> 332         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     333
#     334         # construct the engine and evaluate the parsed expression
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     762         self.parser = parser
#     763         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 764         self.terms = self.parse()
#     765
#     766     @property
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in parse(self)
#     779     def parse(self):
#     780         """Parse an expression"""
# --> 781         return self._visitor.visit(self.expr)
#     782
#     783     @property
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     379             raise SyntaxError("only a single expression is allowed")
#     380         expr = node.body[0]
# --> 381         return self.visit(expr, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     382
#     383     def visit_Expr(self, node, **kwargs):
# --> 384         return self.visit(node.value, **kwargs)
#     385
#     386     def _rewrite_membership_op(self, node, left, right):
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     674             op = self.translate_In(ops[0])
#     675             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 676             return self.visit(binop)
#     677
#     678         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     495
#     496     def visit_BinOp(self, node, **kwargs):
# --> 497         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     498         left, right = self._maybe_downcast_constants(left, right)
#     499         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     414     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     415         if left is None:
# --> 416             left = self.visit(node.left, side="left")
#     417         if right is None:
#     418             right = self.visit(node.right, side="right")
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     373         method = "visit_" + type(node).__name__
#     374         visitor = getattr(self, method)
# --> 375         return visitor(node, **kwargs)
#     376
#     377     def visit_Module(self, node, **kwargs):
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     508
#     509     def visit_Name(self, node, **kwargs):
# --> 510         return self.term_type(node.id, self.env, **kwargs)
#     511
#     512     def visit_NameConstant(self, node, **kwargs):
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      80         tname = str(name)
#      81         self.is_local = tname.startswith(_LOCAL_TAG) or tname in _DEFAULT_GLOBALS
# ---> 82         self._value = self._resolve_name()
#      83         self.encoding = encoding
#      84
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/ops.py in _resolve_name(self)
#      97
#      98     def _resolve_name(self):
# ---> 99         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     100         self.update(res)
#     101
#
# ~/software/django-tmv/tmv/venv/lib/python3.6/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     201                 from pandas.core.computation.ops import UndefinedVariableError
#     202
# --> 203                 raise UndefinedVariableError(key, is_local)
#     204
#     205     def swapkey(self, old_key: str, new_key: str, new_value=None):
#
# UndefinedVariableError: name 'upper_pred' is not defined

# %%
done = pd.read_csv('../data/doc_continent.csv')

df = df[~df['id'].isin(done['id'])]
df.shape
# Out:
# (13884, 12)

# %%
from mordecai import Geoparser
geo = Geoparser()

geo.geoparse("I took the tube from Oxford Circus to London Bridge, via Bank")
# Out:
# [{'country_conf': 0.611725,
#   'country_predicted': 'GBR',
#   'geo': {'admin1': 'England',
#    'country_code3': 'GBR',
#    'feature_class': 'S',
#    'feature_code': 'BDG',
#    'geonameid': '6619889',
#    'lat': '51.50821',
#    'lon': '-0.08763',
#    'place_name': 'London Bridge'},
#   'spans': [{'end': 51, 'start': 38}],
#   'word': 'London Bridge'}]

# %%
places = []
geos = []

for i, row in df.iterrows():
    
    t = row['title'] + row['content']
    t = t.split("Copyright (C)")[0] 
    t = re.split("\([C-c]\) [1-2][0-9]{3} Elsevier",t)[0] 
    t = t.split("Published by Elsevier")[0] 
    t = t.split("Copyright. (C)")[0] 
    t = re.split("\. \(C\) [1-2][0-9]{3} ",t)[0] 
    t = re.split("\. \(C\) Copyright",t)[0]     
    
    gp = geo.geoparse(t)
    
    rplaces = []
    continent = None
    for p in gp:
        try:
            a2 = country_alpha3_to_country_alpha2(p["country_predicted"])
            continent = country_alpha2_to_continent_code(a2)
        except:
            pass
        if "geo" in p:
            try:
                a2 = country_alpha3_to_country_alpha2(p["geo"]["country_code3"])
                continent = country_alpha2_to_continent_code(a2)
            except:
                pass
            p["geo"]["doc_id"] = row['id']
            p["geo"]["word"] = p["word"]
            p["geo"]["country_predicted"] = p["country_predicted"]
            p["geo"]["country_conf"] = p["country_conf"]
            geos.append(p["geo"])
        rplaces.append(p)
    df.loc[i,"continent"] = continent
    df.loc[i,"places"] = len(rplaces)

# %%
geo_df = pd.DataFrame.from_dict(geos)
geo_df.head()
# Out:
#      admin1       lat        lon country_code3 geonameid  \
# 0  Zhejiang  29.87819  121.54945           CHN   1799397
# 1        NA  30.59822  121.08953           CHN  10098466
# 2  Zhejiang  29.16667        120           CHN   1784764
# 3  Zhejiang  29.16667        120           CHN   1784764
# 4        NA        62         10           NOR   3144096
#
#               place_name feature_class feature_code   doc_id
# 0                 Ningbo             P        PPLA2  1859208
# 1  Sea View Hangzhou Bay             S          HTL  1859208
# 2         Zhejiang Sheng             A         ADM1  1859208
# 3         Zhejiang Sheng             A         ADM1  1859208
# 4      Kingdom of Norway             A         PCLI  3323085

# %%
old_geo_df = pd.read_csv('../data/geo_df.csv')
print(old_geo_df.shape)
new_geo_df = pd.concat([old_geo_df,geo_df])
new_geo_df.to_csv('../data/new_geo_df.csv', index=False)
# Out:
# (164006, 9)

# %%
print(new_geo_df.shape)
# Out:
# (194919, 9)

# %%
place_df = pd.DataFrame.from_dict(places)
place_df.head()
# Out:
#            word                           spans country_predicted  \
# 0        Ningbo    [{'start': 327, 'end': 333}]               CHN
# 1  Hangzhou Bay    [{'start': 432, 'end': 444}]               CHN
# 2      Zhejiang    [{'start': 446, 'end': 454}]               CHN
# 3      Zhejiang  [{'start': 1146, 'end': 1154}]               CHN
# 4        Norway     [{'start': 97, 'end': 103}]               NOR
#
#    country_conf                                                geo   doc_id
# 0      0.988199  {'admin1': 'Zhejiang', 'lat': '29.87819', 'lon...  1859208
# 1      0.988199  {'admin1': 'NA', 'lat': '30.59822', 'lon': '12...  1859208
# 2      0.988199  {'admin1': 'Zhejiang', 'lat': '29.16667', 'lon...  1859208
# 3      0.988199  {'admin1': 'Zhejiang', 'lat': '29.16667', 'lon...  1859208
# 4      0.999811  {'admin1': 'NA', 'lat': '62', 'lon': '10', 'co...  3323085

# %%
old_place_df = pd.read_csv('../data/place_df.csv')
print(old_place_df.shape)
new_place_df = pd.concat([old_place_df,place_df])
new_place_df.to_csv('../data/new_place_df.csv', index=False)
# Out:
# (286355, 7)

# %%
df[['id','continent']].to_csv('../data/doc_continent.csv',index=False)
